# %% [markdown]
# # PGA vs SE(3)
#
# Jupyter example for interactive rigid body motion visualization in `SE(3)` and PGA motor form.

# %%
import sys
from pathlib import Path

project_root = Path.cwd()
if not (project_root / "src").exists():
    project_root = project_root.parent

sys.path.insert(0, str(project_root))

from src.viewers import pga_rigid_body_viewer, se3_rigid_body_viewer  # noqa: E402

# %% [markdown]
# ## SE(3) visualization

# %%
se3_rigid_body_viewer()

# %% [markdown]
# ## PGA motor visualization

# %%
pga_rigid_body_viewer()
